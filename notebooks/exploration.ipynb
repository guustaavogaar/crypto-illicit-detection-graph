# %% [markdown]
# # Exploración del Dataset de Blockchain
#
# En este notebook exploraremos las transacciones de blockchain para entender la estructura de los datos antes de cargarlos en Neo4j.

# %%
import polars as pl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
